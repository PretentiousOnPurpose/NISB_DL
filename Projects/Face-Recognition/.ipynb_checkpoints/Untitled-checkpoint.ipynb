# %%
import numpy as np
import glob
import copy

# %%
imgs = sorted(glob.glob("*/*.pgm"))

# %%
imgs
# Out:
# ['s1/1.pgm',
#  's1/10.pgm',
#  's1/2.pgm',
#  's1/3.pgm',
#  's1/4.pgm',
#  's1/5.pgm',
#  's1/6.pgm',
#  's1/7.pgm',
#  's1/8.pgm',
#  's1/9.pgm',
#  's2/1.pgm',
#  's2/10.pgm',
#  's2/2.pgm',
#  's2/3.pgm',
#  's2/4.pgm',
#  's2/5.pgm',
#  's2/6.pgm',
#  's2/7.pgm',
#  's2/8.pgm',
#  's2/9.pgm',
#  's3/1.pgm',
#  's3/10.pgm',
#  's3/2.pgm',
#  's3/3.pgm',
#  's3/4.pgm',
#  's3/5.pgm',
#  's3/6.pgm',
#  's3/7.pgm',
#  's3/8.pgm',
#  's3/9.pgm']

# %%
x = []

# %%
for e in range(1, 11):
    for h in range(1, 11):
        for i in range(1, 11):
            x.append(['s2/{}.pgm'.format(e), 's2/{}.pgm'.format(h), 's1/{}.pgm'.format(i)])

# %%
x
# Out:
# [['s1/1.pgm', 's1/1.pgm', 's2/1.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/2.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/3.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/4.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/5.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/6.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/7.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/8.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/9.pgm'],
#  ['s1/1.pgm', 's1/1.pgm', 's2/10.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/1.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/2.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/3.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/4.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/5.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/6.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/7.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/8.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/9.pgm'],
#  ['s1/1.pgm', 's1/2.pgm', 's2/10.pgm'],
#  ['s1/1.pgm', 's1/3.pgm', 's2/1.pgm'],
#  ['s1/1.pgm', 's1/3.pgm', 's2/2.pgm'],
#  ['s1/1.pgm', 's1/3.pgm', 's2/3.pgm'],
#  ['s1/1.pgm', 's1/3.pgm', 's2/4.pgm'],
# ...

# %%
np.save("imgs", x)
